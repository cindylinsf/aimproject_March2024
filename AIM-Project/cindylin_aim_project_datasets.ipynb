# %% [markdown]
# Creating Datasets
#
# - Dutch Golden Age -- Age of Vermeer Master Dataset: Downloaded the dataset from Frick Collection's Github page. It is compiled by its Digital Art History Lab [DAHL]( https://www.frick.org/research/DAHL)
# - The dataset contains a lot of files, but not all have image URLs to scrape off the web. So a manual cleanup was done first to remove any irrelevant files.
# - The code used here in this notebook is largely from the class. I also made some modification with the help of ChatGPT.

# %%
import json
import zipfile
import os

# Path to the DAHL dataset zip file
zip_path = '../AIM-Project/age-of-vermeer-master.zip'

# Temporary directory to extract files
temp_dir = 'temp_extracted_jsons'

# Create a temporary directory
os.makedirs(temp_dir, exist_ok=True)

# Initialize an empty list to hold merged data
merged_data = []

# Extract files
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # Extract only .json files
    for file in zip_ref.namelist():
        if file.endswith('.json'):
            zip_ref.extract(file, temp_dir)
            # Read the extracted json file and append its content to merged_data
            with open(os.path.join(temp_dir, file), 'r') as json_file:
                data = json.load(json_file)
                merged_data.append(data)

# Optionally, remove the temporary directory and its contents after merging
import shutil
shutil.rmtree(temp_dir)

# Now, merged_data contains all merged JSON data

# Saving the merged data to a new JSON file
with open('merged.json', 'w') as outfile:
    json.dump(merged_data, outfile, indent=4)

# merged.json now contains all the merged data from the .json files in the zip archive.

# %% [markdown]
# The readme from the dataset was unclear in terms of how the information was organized. Now that I have merged the 6 different .json files from the dataset, I want to remove any duplicated URLs in the merged.json file.

# %%
# Load the merged JSON data
with open('merged.json', 'r') as file:
    data = json.load(file)

# Initialize a set to keep track of unique URLs
unique_urls = set()

# Initialize a list to store cleaned data without duplicate URLs
cleaned_data = []

for item in data:
    # If item is a dictionary, process it directly
    if isinstance(item, dict):
        url = item.get('Image Link')
        if url not in unique_urls:
            unique_urls.add(url)
            cleaned_data.append(item)
    # If item is a list, iterate through each dictionary in the list
    elif isinstance(item, list):
        for sub_item in item:
            # Ensure sub_item is a dictionary before attempting to access 'Image Link'
            if isinstance(sub_item, dict):
                url = sub_item.get('Image Link')
                if url not in unique_urls:
                    unique_urls.add(url)
                    cleaned_data.append(sub_item)
            else:
                # Handle cases where sub_item is not a dictionary
                print("Encountered a non-dictionary item within a list:", sub_item)
    else:
        # Log any items that are neither dictionaries nor lists
        print("Encountered an unsupported item:", item)

# Save the cleaned data back to a new or the same JSON file
with open('cleaned_merged.json', 'w') as outfile:
    json.dump(cleaned_data, outfile, indent=4)

# %% [markdown]
# Not all the records in the cleaned_merged.json file have URLs, I need to clean the dataset again.

# %%
# Load the JSON file
with open('cleaned_merged.json', 'r') as file:
    data = json.load(file)

# Filter out any records that don't have "https://" in their "Image Link"
filtered_data = [record for record in data if "https://" in record.get("Image Link", "")]

# Save the filtered dataset to a new file, excluding records without "https://" in the Image Link
with open('filtered_cleaned_merged.json', 'w') as file:
    json.dump(filtered_data, file, indent=4)

print(f"The filtered dataset has been saved. It includes {len(filtered_data)} records, each with 'https://' in the Image Link.")
# Out:
# The filtered dataset has been saved. It includes 92 records, each with 'https://' in the Image Link.

# %% [markdown]
# Now, all the URLs are ready to be scraped.

# %%
pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Using cached soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.12.3 soupsieve-2.5
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from pathlib import Path

# Define the directory where images will be saved
save_dir = Path("../AIM-Project/age_of_vermeer_master_images")
os.makedirs(save_dir, exist_ok=True)

# Load your JSON data
# Assuming it's already loaded into a variable named `data`

# Function to download an image given its URL
def download_image(image_url, save_path):
    try:
        response = requests.get(image_url, stream=True)
        if response.status_code == 200:
            with open(save_path, 'wb') as f:
                f.write(response.content)
            print(f"Downloaded {image_url}")
        else:
            print(f"Failed to download {image_url}")
    except Exception as e:
        print(f"Error downloading {image_url}: {e}")

# Function to fetch and parse a webpage to find an image URL, then download it
def scrape_and_download_image(page_url, save_dir):
    try:
        response = requests.get(page_url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            # Example: Find the first <img> element (You might need to adjust this based on your needs)
            img_tag = soup.find('img')
            if img_tag and 'src' in img_tag.attrs:
                img_url = urljoin(page_url, img_tag['src'])
                image_name = os.path.basename(img_url)
                save_path = save_dir / image_name
                download_image(img_url, save_path)
            else:
                print(f"No image found at {page_url}")
        else:
            print(f"Failed to fetch page {page_url}")
    except Exception as e:
        print(f"Error fetching page {page_url}: {e}")

# Iterate through each record and attempt to scrape and download the image
for record in data:
    page_url = record.get("Image Link", "")
    if page_url:
        scrape_and_download_image(page_url, save_dir)
# Out:
# Downloaded https://www.facebook.com/tr?id=962351770479675&ev=PageView&noscript=1
# Downloaded https://www.nationalgalleries.org/sites/default/files/styles/thumbnail/public/externals/94784.jpg?itok=KFv92fdy
# Downloaded https://skd-online-collection.skd.museum/thumb/302/17dcd117-d81a-438c-aa1e-2b8655acf33e.jpg
# Downloaded https://www.metmuseum.org/art/collection/search/437878
# Downloaded https://skd-online-collection.skd.museum/thumb/122/719ac509-a48c-4306-8ac1-e3c4e60e492d.jpg
# Downloaded https://collections.frick.org:443/internal/media/dispatcher/20123/resize%3Aformat%3Dzoomify;jsessionid=58D1CC327C1401B6FD5423A3B304EE51
# No image found at https://www.rijksmuseum.nl/en/collection/SK-A-2344
# Downloaded https://collections.frick.org:443/internal/media/dispatcher/18885/resize%3Aformat%3Dzoomify;jsessionid=F6C84EDFCE1D6D3E99257DF1DBF026B2
# Failed to fetch page https://www.3landesmuseen.de/Hollaendische-Malerei-17-und-18-Jahrhu.644.0.html
# Failed to fetch page https://www.rijksmuseum.nl/en/vermeers-the-little-street-discovered/objects#/SK-A-2860,2
# Downloaded https://www.facebook.com/tr?id=962351770479675&ev=PageView&noscript=1
# Downloaded https://www.metmuseum.org/art/collection/search/437881
# Downloaded https://www.metmuseum.org/art/collection/search/437880
# Downloaded https://www.rct.uk/sites/all/themes/rctr/assets/components/patterns/header/logo.svg
# Downloaded https://www.gardnermuseum.org/experience/collection/10966
# Failed to fetch page https://www.rijksmuseum.nl/en/vermeers-the-little-street-discovered/objects#/SK-C-251,1
# Downloaded https://media.nga.gov/iiif/c948cf32-e6c7-41a0-a053-0ad0562960c4/full/!750,900/0/default.jpg
# Downloaded https://media.nga.gov/iiif/ea55879e-57f1-494d-9043-6dedb384bdc8/full/!750,900/0/default.jpg
# Downloaded https://collections.frick.org:443/internal/media/dispatcher/20937/resize%3Aformat%3Dzoomify;jsessionid=E9AC511C016938F9479D1704706B812E
# Downloaded https://www.facebook.com/tr?id=962351770479675&ev=PageView&noscript=1
# Downloaded https://www.metmuseum.org/art/collection/search/437879
# Downloaded https://media.nga.gov/iiif/b705a403-3496-42e8-abf5-a37e34c32198/full/!750,900/0/default.jpg
# Downloaded https://media.nga.gov/iiif/1829584c-abf5-4c25-9977-8d13687a7406/full/!750,900/0/default.jpg
# Downloaded https://www.khm.at/typo3conf/ext/objectdb/Resources/Public/Images/kunstpatenschaft.png
# No image found at https://upload.wikimedia.org/wikipedia/commons/0/0e/Johannes_Vermeer_-_The_Astronomer_-_WGA24685.jpg
# No image found at https://sammlung.staedelmuseum.de/en/work/the-geographer
# Downloaded https://api-www.louvre.fr/sites/default/files/2021-02/GP110591.jpg
# Downloaded https://www.nationalgallery.ie/themes/custom/ngi/logo.png
# Downloaded https://www.metmuseum.org/art/collection/search/437877
# Downloaded https://www.nationalgallery.org.uk/v2/img/logos/ng-logo-white-320.png
# Downloaded https://www.nationalgallery.org.uk/v2/img/logos/ng-logo-white-320.png
# Downloaded https://www.english-heritage.org.uk/eh-logo-top.svg
# Failed to fetch page https://www.theleidencollection.com/artwork/young-woman-seated-at-a-virginal/
# Failed to download https://upload.wikimedia.org/wikipedia/commons/5/53/E._Boursse_Bellenblazers.gif?20080929190631
# Failed to fetch page https://www.mutualart.com/Artwork/Portrait-of-a-boy-in-a-white-shirt/B31CCD9A4F84009D
# Downloaded https://www.hydecollection.org/wp-content/themes/HydeCollection/images/logo-sticky.png
# Failed to download https://upload.wikimedia.org/wikipedia/commons/thumb/c/cb/Pieter_de_Hooch_-_Soldiers_Playing_Cards_-_WGA11685.jpg/220px-Pieter_de_Hooch_-_Soldiers_Playing_Cards_-_WGA11685.jpg
# Failed to fetch page https://www.museumdefundatie.nl/en/explore-the-collection/object/?pagina=0&id=0&vervaardigers=&techniek=&datums=&query=van+meegeren
# Downloaded https://static.boijmans.nl/dist/assets/img/popup/popupoptie1.jpeg
# Failed to fetch page https://rkd.nl/en/explore/images/record?query=Reyer+Jacobsz.+van+Blommendael&start=5
# Failed to fetch page https://rkd.nl/en/explore/images/record?query=Johannes+Natus&start=2
# Downloaded https://www.pubhist.com/images/logosmall.jpg
# Failed to fetch page https://rkd.nl/en/explore/images/record?query=Jacob+Martsen&start=2
# Failed to fetch page https://rkd.nl/en/explore/images/record?filters%5Bobjectcategorie%5D%5B0%5D=drawing&query=johannes+vermeer&start=4
# Failed to fetch page https://rkd.nl/en/explore/images/record?query=Olivier+van+Deuren&start=2
# Error fetching page Image can be found in The Burlington Magazine for Connoisseurs, Volume 15, page 247- https://books.google.com/books?id=3sw-AQAAMAAJ&pg=PR7&lpg=PR7&dq=sackville+gallery+girl+pouring+wine&source=bl&ots=Et7ZRbF9oj&sig=ACfU3U33TcWAm5DQ2dVLtxB5-geQVvtHcA&hl=en&sa=X&ved=2ahUKEwieg_6EmefiAhUPmeAKHaCTDp0Q6AEwBnoECAkQAQ#v=onepage&q=sackville%20gallery%20girl%20pouring%20wine&f=false: No connection adapters were found for 'Image can be found in The Burlington Magazine for Connoisseurs, Volume 15, page 247- https://books.google.com/books?id=3sw-AQAAMAAJ&pg=PR7&lpg=PR7&dq=sackville+gallery+girl+pouring+wine&source=bl&ots=Et7ZRbF9oj&sig=ACfU3U33TcWAm5DQ2dVLtxB5-geQVvtHcA&hl=en&sa=X&ved=2ahUKEwieg_6EmefiAhUPmeAKHaCTDp0Q6AEwBnoECAkQAQ#v=onepage&q=sackville%20gallery%20girl%20pouring%20wine&f=false'
# Failed to fetch page https://upload.wikimedia.org/wikipedia/commons/2/2a/A_graduation_ceremony_at_Leiden_University_about_1650%2C_by_Hendrick_van_der_Burgh.jpg
# Failed to fetch page https://rkd.nl/en/explore/images/record?query=The+Harpsichord+Lesson&start=0
# Error fetching page https://digitalcollections.frick.org/digico/#/: HTTPSConnectionPool(host='digitalcollections.frick.org', port=443): Max retries exceeded with url: /digico/ (Caused by SSLError(SSLError(1, '[SSL: UNSAFE_LEGACY_RENEGOTIATION_DISABLED] unsafe legacy renegotiation disabled (_ssl.c:1006)')))
# No image found at https://www.philamuseum.org/collections/permanent/102333.html?mulR=1849596643|1
# Downloaded https://en.wikipedia.org/static/images/icons/wikipedia.png
# Failed to fetch page https://upload.wikimedia.org/wikipedia/commons/0/04/Jesus_unter_den_Schriftgelehrten_von_Han_van_Meegeren.jpg
# Downloaded https://media.nga.gov/iiif/b386f7e0-cacb-495a-9eef-3c96f5a6ce14/full/!750,900/0/default.jpg
# No image found at https://www.philamuseum.org/collections/permanent/102282.html?mulR=2013828767|5
# No image found at https://www.rijksmuseum.nl/en/collection/SK-A-4019
# Downloaded https://static.boijmans.nl/dist/assets/img/popup/popupoptie1.jpeg
# Downloaded https://www.metmuseum.org/art/collection/search/437352
# Failed to fetch page https://rkd.nl/nl/explore/images/267390
# Downloaded https://artuk.org/skins/artuk/assets/img/logos/ArtUK_Logo_RGB_White.png
# Downloaded https://www.fine-arts-museum.be/assets/img/alert-toggle.svg
# Failed to fetch page https://rkd.nl/nl/explore/images/5650
# Downloaded https://www.mfab.hu/app/themes/szepmu/assets/images/logo-szepmu-eng.svg
# Downloaded https://www.metmuseum.org/art/collection/search/435757?&searchField=ArtistCulture&sortBy=Relevance&ft=Sebastien+Bourdon&offset=0&rpp=20&amp;pos=17
# Failed to fetch page https://rkd.nl/nl/explore/images/41838
# Failed to fetch page https://twitter.com/PP_Rubens/status/1102432716874756096/photo/0
# Downloaded https://www.christies.com/img/LotImages/2014/AMS/2014_AMS_03052_0229_000(dutch_school_17th_century_a_servant_girl_sleeping035718).jpg?w=1
# Downloaded https://media.nga.gov/iiif/53b11b32-8e95-41d4-bb53-a55931823419/full/!750,900/0/default.jpg
# Failed to fetch page https://www.mutualart.com/Artwork/Nature-morte-aux-fruits/4AEB1EC27F360A95
# Failed to fetch page https://apps.carleton.edu/kettering/stone-ferrier/?module_api=image_detail&module_identifier=module_identifier-mcla-ImageSidebarModule-mloc-pre_sidebar-mpar-da9af63edc444779df2c954dfc8d4d40&image_id=1089509
# Downloaded https://www.metmuseum.org/art/collection/search/436678
# Failed to fetch page https://www.mutualart.com/Artwork/STREET-SCENE-WITH-FIGURES-IN-CONVERSATIO/43134034A9D97322
# Failed to fetch page https://rkd.nl/nl/explore/images/268750
# No image found at https://sammlung.staedelmuseum.de/en/work/view-of-delft
# Failed to fetch page https://rkd.nl/explore/images/196472
# Downloaded https://api-www.louvre.fr/sites/default/files/2021-02/GP110591.jpg
# Failed to fetch page https://rkd.nl/explore/images/11392
# No image found at https://wallacelive.wallacecollection.org/eMP/eMuseumPlus?service=direct/1/ResultListView/result.t1.collection_list.$TspTitleImageLink.link&sp=10&sp=Scollection&sp=SfieldValue&sp=0&sp=0&sp=2&sp=SdetailList&sp=0&sp=Sdetail&sp=0&sp=F&sp=T&sp=1
# Downloaded https://www.metmuseum.org/art/collection/search/437882?exhibitionId=%7b4318132f-0779-46f5-a12c-54823e3da1b2%7d&amp;oid=437882&amp;pos=1&amp;ft=*
# Downloaded https://www.teylersmuseum.nl/en/collection/art/r-010-zittende-jongeman-bij-ton-met-het-hoofd-naar-links
# Failed to fetch page https://rkd.nl/explore/images/59067
# Failed to fetch page https://rkd.nl/explore/images/55321
# Failed to fetch page https://rkd.nl/en/explore/images/284012
# Downloaded https://www.codart.nl/wp-content/themes/codart/dist/img/codart-logo-white.svg
# Failed to fetch page https://rkd.nl/en/explore/images/281769
# Downloaded https://skd-online-collection.skd.museum/Content/images/Teaser/GAM_1034_Detail2_klein.jpg
# Downloaded https://skd-online-collection.skd.museum/Content/images/Teaser/GAM_1034_Detail2_klein.jpg
# No image found at https://www.rijksmuseum.nl/en/collection/SK-A-2345
# Failed to fetch page https://www.rijksmuseum.nl/en/vermeers-the-little-street-discovered/objects#/SK-A-2860,3
# Downloaded https://www.rct.uk/sites/all/themes/rctr/assets/components/patterns/header/logo.svg
# Downloaded https://www.gardnermuseum.org/experience/collection/10967
# Failed to fetch page https://www.rijksmuseum.nl/en/vermeers-the-little-street-discovered/objects#/SK-C-251,2
# Failed to fetch page https://www.rijksmuseum.nl/en/vermeers-the-little-street-discovered/objects#/SK-A-1595,4

# %% [markdown]
# Most images downloaded were not images since many URLs linked in the dataset are outdated. So I ended up not using the datasets I found online. Instead, I searched for images on Pinterested and created a Pinterest board, pulling 17th Century Dutch portraits of subjects with large lace collars. After installing gallery-dl via command line into my project conda environment, I scraped a Pinterest board for the first dataset.

# %%
# !gallery-dl "https://www.pinterest.co.uk/clin0320233/dutch-portrait-project/"
# Out:
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958496029.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958496024.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958496022.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958496019.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958496018.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958496013.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958496011.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958496008.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958496000.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495997.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495996.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495993.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495992.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495987.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495972.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495969.png
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495965.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495961.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495955.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495951.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495949.png
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495948.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495945.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495944.png
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495943.png
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495942.png
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495941.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495939.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495937.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495936.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495935.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495933.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495931.png
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495930.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495929.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495927.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495925.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495924.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495923.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495920.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495918.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495916.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495914.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495912.png
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495911.png
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495910.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495904.png
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495903.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495896.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495888.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495887.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495886.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495885.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495884.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495883.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495881.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495880.png
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495879.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495878.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495876.png
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495874.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495873.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495872.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495870.png
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495869.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495868.png
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495867.jpg
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495865.png
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495863.png
# ./gallery-dl/pinterest/clin0320233/Dutc…rtraits/pinterest_885661082958495862.jpg

# %% [markdown]
# After training with Dreambooth with two pre-trained stable diffusion models, I feel the end results are not close to my original intended results. So I scraped Hendrik Kerstens' photographic work directly to create a second dataset. I used Danziger Gallery's artist profile (https://www.danzigergallery.com/artists/hendrik-kerstens2?view=slider#1) to source the photos. Pinned them onto a Pinterest Board and repeat the code above from class.

# %%
# !gallery-dl "https://www.pinterest.co.uk/clin0320233/hendrik-kerstens/"
# Out:
# ./gallery-dl/pinterest/clin0320233/Hend…erstens/pinterest_885661082958572253.jpg
# ./gallery-dl/pinterest/clin0320233/Hend…erstens/pinterest_885661082958572250.jpg
# ./gallery-dl/pinterest/clin0320233/Hend…erstens/pinterest_885661082958572247.jpg
# ./gallery-dl/pinterest/clin0320233/Hend…erstens/pinterest_885661082958572241.jpg
# ./gallery-dl/pinterest/clin0320233/Hend…erstens/pinterest_885661082958572240.jpg
# ./gallery-dl/pinterest/clin0320233/Hend…erstens/pinterest_885661082958572235.jpg
# ./gallery-dl/pinterest/clin0320233/Hend…erstens/pinterest_885661082958572227.jpg
# ./gallery-dl/pinterest/clin0320233/Hend…erstens/pinterest_885661082958572225.jpg
# ./gallery-dl/pinterest/clin0320233/Hend…erstens/pinterest_885661082958572223.jpg
# ./gallery-dl/pinterest/clin0320233/Hend…erstens/pinterest_885661082958572219.jpg
# ./gallery-dl/pinterest/clin0320233/Hend…erstens/pinterest_885661082958572215.jpg
# ./gallery-dl/pinterest/clin0320233/Hend…erstens/pinterest_885661082958572213.jpg
# ./gallery-dl/pinterest/clin0320233/Hend…erstens/pinterest_885661082958572207.jpg
# ./gallery-dl/pinterest/clin0320233/Hend…erstens/pinterest_885661082958572204.jpg
# ./gallery-dl/pinterest/clin0320233/Hend…erstens/pinterest_885661082958572200.jpg
